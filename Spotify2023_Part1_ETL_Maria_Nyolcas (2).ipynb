# %% [markdown]
# # SPOTIFY DATASET

# %% [markdown]
# ### Imagine you are working with a music group or artist to help them make more money on Spotify.
# - Artists on spotify make money based on streams.
# - Investigate the data to help your client get as many streams as possible.
# - What can an artist do to get more streams?
# - What song charactaristics are related to the number of streams?

# %% [markdown]
# ## DOWNLOAD THE DATA

# %%
# Import libraries
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np

# %%
# Go to https://www.kaggle.com/datasets/nelgiriyewithana/top-spotify-songs-2023/data and download the dataset

# %%
# Open the csv in the notebook. Name it df. You might have to change the encoding
df = pd.read_csv("C:\\Users\\nyolc\\OneDrive\\Asztali gép\\CS251\\spotify-2023.csv", encoding = "ISO-8859-1")

# %%
# to show all columns:
pd.set_option('display.max_columns', None);

# %% [markdown]
# ## EXPLORING THE DATA

# %%
# View the first 3 rows
df.head()
df.shape
# Out:
# (953, 24)

# %%
# View the last 3 rows
df.tail(3)
# Out:
#                track_name      artist(s)_name  artist_count  released_year  \
# 950  A Veces (feat. Feid)  Feid, Paulo Londra             2           2022
# 951         En La De Ella  Feid, Sech, Jhayco             3           2022
# 952                 Alone           Burna Boy             1           2022
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 950              11             3                   573                  0
# 951              10            20                  1320                  0
# 952              11             4                   782                  2
#
#        streams  in_apple_playlists  in_apple_charts in_deezer_playlists  \
# 950   73513683                   2                0                   7
# 951  133895612                  29               26                  17
# 952   96007391                  27               18                  32
#
# ...

# %%
# view a random sample from the dataset
df.sample(5)
# Out:
#                                  track_name             artist(s)_name  \
# 10                                un x100to  Bad Bunny, Grupo Frontera
# 810                           TUS Lï¿½ï¿½GR                 Sech, Mora
# 783                      Worldwide Steppers             Kendrick Lamar
# 697  Something In The Way - Remastered 2021                    Nirvana
# 646                               Miï¿½ï¿½n        Tini, Maria Becerra
#
#      artist_count  released_year  released_month  released_day  \
# 10              2           2023               4            17
# 810             2           2022               4             1
# 783             1           2022               5            13
# 697             1           1991               9            24
# 646             2           2021               4            29
#
#      in_spotify_playlists  in_spotify_charts    streams  in_apple_playlists  \
# 10                   2876                 40  505671438                  41
# ...

# %%
# view the shape (rows and columns)
df.shape
# Out:
# (953, 24)

# %%
# Check if any columns have null values

# %%
#what is the track name of the third row of the database?
df.iloc[2,0]
# Out:
# 'vampire'

# %%
#what is the released year of the third to last row of the database?
df.iloc[-3,3]
# Out:
# 2022

# %%
#tow collumns have null values. Which one has more?
df.isnull().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %%
#Are there any duplicate rows in the dataset?
df.duplicated().sum()
# Out:
# 0

# %%
#Wgat is dtype of streams?
df["streams"].dtype
# Out:
# dtype('O')

# %%
#

# %%
#what is the minimum released year?
df["released_year"].min()
# Out:
# 1930

# %%
#total null values in the dataset
df.isnull().sum().sum()
# Out:
# 145

# %%
# check for duplicated values:
df.duplicated().sum()
# Out:
# 0

# %%
# View the columns
df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %%
# We are only going to look at columns related to spotify 
# either drop the unrelated columns or select only the columns you want to keep
df = df.drop(columns=['in_apple_playlists', 'in_apple_charts', 'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts'])

# %%
# These columns should be removed: 
# 'in_apple_playlists', 'in_apple_charts','in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts'

# %%
# You should be left with these columns:
df
# ['track_name', 'artist(s)_name', 'artist_count', 'released_year', 'released_month', 'released_day', 
# 'in_spotify_playlists','in_spotify_charts', 'streams', 'bpm','key', 'mode', 'danceability_%', 'valence_%', 
# 'energy_%','acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%']
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
# Check out the info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   bpm                   953 non-null    int64
#  10  key                   858 non-null    object
#  11  mode                  953 non-null    object
#  12  danceability_%        953 non-null    int64
#  13  valence_%             953 non-null    int64
#  14  energy_%              953 non-null    int64
# ...

# %%
# describe the dataframe

round(df.describe())
# Out:
#        artist_count  released_year  released_month  released_day  \
# count         953.0          953.0           953.0         953.0
# mean            2.0         2018.0             6.0          14.0
# std             1.0           11.0             4.0           9.0
# min             1.0         1930.0             1.0           1.0
# 25%             1.0         2020.0             3.0           6.0
# 50%             1.0         2022.0             6.0          13.0
# 75%             2.0         2022.0             9.0          22.0
# max             8.0         2023.0            12.0          31.0
#
#        in_spotify_playlists  in_spotify_charts    bpm  danceability_%  \
# count                 953.0              953.0  953.0           953.0
# mean                 5200.0               12.0  123.0            67.0
# std                  7898.0               20.0   28.0            15.0
# min                    31.0                0.0   65.0            23.0
# ...

# %% [markdown]
# ### Looking at the above table:
# 1. what is the max value of artist_count?
# 2. what is median (50%) value for amount of times in spotify playlists?

# %%
# 1. Max value of artist count: 
df["artist_count"].max()

# 2. Median value for amount of times on spotify playlists: 
df["in_spotify_playlists"].median()
# Out:
# 2224.0

# %%
# Use iloc to focus on rows 200 - 205 and columns 3-7
df.iloc[200:206, 3:8]
# Out:
#      released_year  released_month  released_day  in_spotify_playlists  \
# 200           2023               6             2                   551
# 201           2023               5             1                   577
# 202           2023               5            11                   955
# 203           2022              11            24                   995
# 204           2023               5            15                   178
# 205           2023               6             2                   290
#
#      in_spotify_charts
# 200                  4
# 201                 14
# 202                 29
# 203                 19
# 204                  6
# 205                 19

# %%
# Use .loc to focus on rows 870-874 and columns ['artist(s)_name' and 'danceability_%']
df.loc[870:874, ['artist(s)_name', 'danceability_%']]
# Out:
#     artist(s)_name  danceability_%
# 870         j-hope              78
# 871  Guns N' Roses              45
# 872      Burna Boy              80
# 873      Rosa Linn              56
# 874          Drake              88

# %%
# use [] to look at rows 20 and 21. 
df[20:22]
# Out:
#                                            track_name  \
# 20                                          LADY GAGA
# 21  I Can See You (Taylorï¿½ï¿½ï¿½s Version) (From...
#
#                               artist(s)_name  artist_count  released_year  \
# 20  Gabito Ballesteros, Junior H, Peso Pluma             3           2023
# 21                              Taylor Swift             1           2023
#
#     released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 20               6            22                   332                 26
# 21               7             7                   516                 38
#
#      streams  bpm key   mode  danceability_%  valence_%  energy_%  \
# 20  86444842  140   F  Minor              65         87        74
# 21  52135248  123  F#  Major              69         82        76
#
#     acousticness_%  instrumentalness_%  liveness_%  speechiness_%
# 20              22                   0          42              4
# ...

# %%
# Find rows with nulls
df[df.isnull().any(axis=1)]
# Out:
#                                             track_name  \
# 12                                             Flowers
# 17   What Was I Made For? [From The Motion Picture ...
# 22                                    I Wanna Be Yours
# 35                                     Los del Espacio
# 44    Barbie World (with Aqua) [From Barbie The Album]
# ..                                                 ...
# 899                                     Hold Me Closer
# 901                                         After LIKE
# 903              B.O.T.A. (Baddest Of Them All) - Edit
# 938                                          Labyrinth
# 940                                      Sweet Nothing
#
#                                         artist(s)_name  artist_count  \
# 12                                         Miley Cyrus             1
# 17                                       Billie Eilish             1
# 22                                      Arctic Monkeys             1
# ...

# %%
df.shape
# Out:
# (953, 19)

# %%
# Look at the unique values in this null row
# Are the values numbers or categories?
df["released_month"].unique()
# Out:
# array([ 7,  3,  6,  8,  5,  4,  1, 12,  2, 10, 11,  9], dtype=int64)

# %%
# We could fill the nulls with the most repeated value, or with a filler value such as 'NA' or 'Unknown'
# Let's fill the nulls with 'Unknown'
df = df.fillna('Unknown')
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
# check that all the nulls have been replaced. The sum of all nulls in the df should be 0
df.isnull().sum().sum()
# Out:
# 0

# %%
#uniwue values in the key column
df["key"].unique()
# Out:
# array(['B', 'C#', 'F', 'A', 'D', 'F#', 'Unknown', 'G#', 'G', 'E', 'A#',
#        'D#'], dtype=object)

# %% [markdown]
# ## REMOVE ROWS

# %%
# One of the columns contains a string that shouldn't be there. the rest of the values in the column are integers. 
# The column type is string due to the one string value. 
# Find the string and disply the entire row which contains the string
# remove the row. 
# reset the index and convert the column to numeric. 
import pandas as pd
df["streams"].unique()
df[~df['streams'].apply(lambda x: str(x).isdigit())]

df = df.drop(574)

# %%
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
# check the dtypes
df.dtypes
# Out:
# track_name              object
# artist(s)_name          object
# artist_count             int64
# released_year            int64
# released_month           int64
# released_day             int64
# in_spotify_playlists     int64
# in_spotify_charts        int64
# streams                 object
# bpm                      int64
# key                     object
# mode                    object
# danceability_%           int64
# valence_%                int64
# energy_%                 int64
# acousticness_%           int64
# instrumentalness_%       int64
# liveness_%               int64
# speechiness_%            int64
# dtype: object

# %%
df.shape
# Out:
# (952, 19)

# %%
#reset the index
df = df.reset_index(drop=True)
df.shape
# Out:
# (952, 19)

# %%
df.tail()
# Out:
#                     track_name      artist(s)_name  artist_count  \
# 947               My Mind & Me        Selena Gomez             1
# 948  Bigger Than The Whole Sky        Taylor Swift             1
# 949       A Veces (feat. Feid)  Feid, Paulo Londra             2
# 950              En La De Ella  Feid, Sech, Jhayco             3
# 951                      Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 947           2022              11             3                   953
# 948           2022              10            21                  1180
# 949           2022              11             3                   573
# 950           2022              10            20                  1320
# 951           2022              11             4                   782
#
#      in_spotify_charts    streams  bpm key   mode  danceability_%  valence_%  \
# ...

# %%
# There is one value that has dtype of string, although it should be an int.
# which column is it? 
# Can you print the first ten rows of that column?
df.streams.values[:10]
# Out:
# array(['141381703', '133716286', '140003974', '800840817', '303236322',
#        '183706234', '725980112', '58149378', '95217315', '553634067'],
#       dtype=object)

# %%
# It looks like the values are all integers, saved as strings
# But, what happens if you try to convert the column type to integer
df.streams=pd.to_numeric(df.streams)
df.streams.dtype

# Try below and see what happens
# Out:
# dtype('int64')

# %%
# One of the valuues in the column is a string. Can we find what row it is in and print the whole row?
# There are a few different ways to do this. See if you can figure one out
df[~df['streams'].apply(lambda x: str(x).isdigit())]
# Out:
# Empty DataFrame
# Columns: [track_name, artist(s)_name, artist_count, released_year, released_month, released_day, in_spotify_playlists, in_spotify_charts, streams, bpm, key, mode, danceability_%, valence_%, energy_%, acousticness_%, instrumentalness_%, liveness_%, speechiness_%]
# Index: []

# %%
# find the row with the value in the dataframe
df[df['streams'] == 'Unknown']
# Out:
# Empty DataFrame
# Columns: [track_name, artist(s)_name, artist_count, released_year, released_month, released_day, in_spotify_playlists, in_spotify_charts, streams, bpm, key, mode, danceability_%, valence_%, energy_%, acousticness_%, instrumentalness_%, liveness_%, speechiness_%]
# Index: []

# %%
#Which released_date is repated 9 times in the dataframe from released_year and released_month and released_day?    
released_date=df.groupby(['released_year', 'released_month', 'released_day']).size().sort_values(ascending=False)

# %%
released_date[released_date==9]
# Out:
# released_year  released_month  released_day
# 2023           3               3               9
# dtype: int64

# %%
#What percent of songs were released on Wednesday round the nearest whole number from released_date?
released_date=df.groupby(['released_year', 'released_month', 'released_day']).size().sort_values(ascending=False)
released_date[released_date==9]/df.shape[0]*100
released_day=df.groupby(['released_day']).size().sort_values(ascending=False)
released_day[4]/df.shape[0]*100
# Out:
# 4.0966386554621845

# %%
#For monday, what is the value of the meadian of streams?
monday=df[df['released_day']==0]
monday['streams'].median()
# Out:
# nan

# %%
#which artist appears 26 times as a main artist split the main artist?
df['artist(s)_name']=df['artist(s)_name'].str.split(',')
df['artist(s)_name']=df['artist(s)_name'].str[0]
df['artist(s)_name'].value_counts()
df['artist(s)_name'].value_counts()
# Out:
# Taylor Swift      36
# The Weeknd        34
# Bad Bunny         26
# SZA               23
# Kendrick Lamar    23
#                   ..
# MC Xenon           1
# Treyce             1
# Leo Santana        1
# Kaifi Khalil       1
# Selena Gomez       1
# Name: artist(s)_name, Length: 458, dtype: int64

# %%
#WHat artist or group appears 6 times as a supporting artist not the main ?
#separate the supporting artists
df['supporting']=df['artist(s)_name'].str.split(',')
list=df['supporting'].value_counts()
list[list==6]
# Out:
# [Bruno Mars]       6
# [Dua Lipa]         6
# [Post Malone]      6
# [Nicki Minaj]      6
# [Justin Bieber]    6
# [Fuerza Regida]    6
# [Kanye West]       6
# [Billie Eilish]    6
# [NewJeans]         6
# [Quevedo]          6
# Name: supporting, dtype: int64

# %%
df.shape
# Out:
# (952, 20)

# %%
df
# Out:
#                               track_name  artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)           Latto             2
# 1                                   LALA     Myke Towers             1
# 2                                vampire  Olivia Rodrigo             1
# 3                           Cruel Summer    Taylor Swift             1
# 4                         WHERE SHE GOES       Bad Bunny             1
# ..                                   ...             ...           ...
# 947                         My Mind & Me    Selena Gomez             1
# 948            Bigger Than The Whole Sky    Taylor Swift             1
# 949                 A Veces (feat. Feid)            Feid             2
# 950                        En La De Ella            Feid             3
# 951                                Alone       Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# ...

# %%
#Which main artist has the highest average bpm?
df.groupby('artist(s)_name')['bpm'].mean().sort_values(ascending=False)
# Out:
# artist(s)_name
# Adassa             206.0
# Stephen Sanchez    202.0
# Andy Williams      202.0
# NMIXX              200.0
# Libianca           198.0
#                    ...
# Kodak Black         73.5
# Duncan Laurence     72.0
# Tulus               72.0
# Queen               71.0
# Residente           71.0
# Name: bpm, Length: 458, dtype: float64

# %%
# Since the value does not include the number of streams, and the number of streams is what we want to analize, 
# lets remove the row
df = df.drop(574)

# %%
# convert to numeric column
df.streams = pd.to_numeric(df.streams)

# %%
# check that the vaues are integers
df.streams.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ## DATE COLUMN

# %%
# import date from correct library
from datetime import date

# %%
# Use apply and lambda functions to combine the date columns (year, month, and day) 
# and insert it in column 6 as a new column called released_date.
df['released_date'] = df.apply(lambda x: date(int(x['released_year']), int(x['released_month']), int(x['released_day'])), axis=1)

# %%
# Check a sample to make sure it all worked
df.sample(5)
# Out:
#                             track_name artist(s)_name  artist_count  \
# 410  INDUSTRY BABY (feat. Jack Harlow)    Jack Harlow             2
# 253                      Glimpse of Us           Joji             1
# 719            Wake Me Up - Radio Edit         Avicii             1
# 220                         Las Morras         BLESSD             2
# 441    All I Want for Christmas Is You   Mariah Carey             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 410           2021               7            23                 13315
# 253           2022               6            10                  6330
# 719           2013               1             1                 50887
# 220           2023               4             4                   291
# 441           1994              10            28                 25653
#
#      in_spotify_charts     streams  bpm key   mode  danceability_%  valence_%  \
# ...

# %% [markdown]
# ## SPLIT STRINGS AND COLUMNS

# %%
# Let's split the artists into two group: 'main_artist' and 'supporting_artists'
# Insert them in columns 2 and 3 of the df
df['main_artist'] = df['artist(s)_name'].str.split(',').str[0]
df['supporting_artists'] = df['artist(s)_name'].str.split(',').str[1]

# %%
# drop 'artist(s)_name'
df = df.drop(columns=['artist(s)_name'])

# %%
# Check a sample to make sure it all worked
df.sample(5)
# Out:
#                                             track_name  artist_count  \
# 848                       Only Love Can Hurt Like This             1
# 245                                          Rich Flex             2
# 666  Cayï¿½ï¿½ La Noche (feat. Cruz Cafunï¿½ï¿½, Ab...             7
# 636                                Permission to Dance             1
# 943                                      The Astronaut             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 848           2014               1             1                  5148
# 245           2022              11             4                  4657
# 666           2022               1            14                  1034
# 636           2021               7             9                  1801
# 943           2022              10            28                   481
#
#      in_spotify_charts    streams  bpm key   mode  danceability_%  valence_%  \
# ...

# %%
# print a sorted list of all the unique main artists
df['main_artist'].unique()
# Out:
# array(['Latto', 'Myke Towers', 'Olivia Rodrigo', 'Taylor Swift',
#        'Bad Bunny', 'Dave', 'Eslabon Armado', 'Quevedo', 'Gunna',
#        'Peso Pluma', 'NewJeans', 'Miley Cyrus', 'David Kushner',
#        'Harry Styles', 'SZA', 'Fifty Fifty', 'Billie Eilish', 'Feid',
#        'Jimin', 'Gabito Ballesteros', 'Arctic Monkeys', 'Bizarrap',
#        'The Weeknd', 'Fuerza Regida', 'Rï¿½ï¿½ma', 'Tainy',
#        'Morgan Wallen', 'Dua Lipa', 'Troye Sivan', 'Karol G', 'Big One',
#        'Yahritza Y Su Esencia', 'Junior H', 'Post Malone', 'Bebe Rexha',
#        'Tyler', 'Nicki Minaj', 'OneRepublic', 'Ariana Grande',
#        'David Guetta', 'Peggy Gou', 'Tom Odell', 'Kali Uchis',
#        'Manuel Turizo', 'dennis', 'PinkPantheress', 'Charlie Puth',
#        'Rauw Alejandro', 'Ozuna', 'Chris Molitor', 'Libianca',
#        'Glass Animals', 'JVKE', 'The Neighbourhood', 'Coldplay', 'd4vd',
#        'Sam Smith', 'Yandel', 'Maria Becerra', 'Vance Joy', 'Em Beihold',
# ...

# %%
# Save the dataframe as a csv 
df.to_csv('spotify-2023-cleaned.csv', index=False)

# %% [markdown]
# # Song Features
#
# ### danceability
# Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
#
# ### energy
# Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
#
# ### key
# The key the track is in. Integers map to pitches using standard Pitch Class notation. E.g. 0 = C, 1 = C#/Db, 2 = D, and so on.
#
# ### loudness
# The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typical range between -60 and 0 db.
#
# ### mode
# Mode indicates the modality (major or minor) of a track, the type of scale from which its melodic content is derived. Major is represented by 1 and minor is 0.
#
# ### speechiness
# Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
#
# ### acousticness
# A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
#
# ### instrumentalness
# Predicts whether a track contains no vocals. "Ooh" and "aah" sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly "vocal". The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
#
# ### liveness
# Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
#
# ### valence
# A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
#
# ### tempo
# The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
#
# -- from https://search.r-project.org/CRAN/refmans/billboard/html/spotify_track_data.html

# %%
df1 = pd.read_csv("C:\\Users\\nyolc\\OneDrive\\Asztali gép\\CS251\\spotify-2023.csv", encoding = "ISO-8859-1")
df1.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  in_apple_charts  \
# ...

# %%
# create a function that cleans the data
def clean_data(df1):
    # drop columns
    df1 = df1.drop(columns=['in_apple_playlists', 'in_apple_charts', 'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts'])
    
    # fill nulls
    df1 = df1.fillna('Unknown')
    
    # remove the row with the string value
    df1 = df1.drop(574)
    
    # convert to numeric
    df1.streams = pd.to_numeric(df1.streams)
    from datetime import date
    # combine date columns
    df1['released_date'] = df1.apply(lambda x: date(int(x['released_year']), int(x['released_month']), int(x['released_day'])), axis=1)
    # create season column
    df1['season'] = df1['released_month'].apply(lambda x: 'Winter' if x in [12, 1, 2] else 'Spring' if x in [3, 4, 5] else 'Summer' if x in [6, 7, 8] else 'Fall')
    #create day of the week column
    df1['day_of_week'] = df1['released_date'].apply(lambda x: x.strftime('%A'))

    
    # split artists as main and supporting artists
    df1['main_artist'] = df1['artist(s)_name'].str.split(',').str[0]
    df1['supporting_artists'] = df1['artist(s)_name'].str.split(',').str[1]
    
    # drop 'artist(s)_name'
    df1 = df1.drop(columns=['artist(s)_name'])
    
    return df1
#show the first 5 rows of the cleaned data
clean_data(df1).head()
# Out:
#                             track_name  artist_count  released_year  \
# 0  Seven (feat. Latto) (Explicit Ver.)             2           2023
# 1                                 LALA             1           2023
# 2                              vampire             1           2023
# 3                         Cruel Summer             1           2019
# 4                       WHERE SHE GOES             1           2023
#
#    released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 0               7            14                   553                147
# 1               3            23                  1474                 48
# 2               6            30                  1397                113
# 3               8            23                  7858                100
# 4               5            18                  3133                 50
#
#      streams  bpm key   mode  danceability_%  valence_%  energy_%  \
# ...

# %%
#reorder the columns
df1 = clean_data(df1)
df1 = df1[['track_name', 'main_artist', 'supporting_artists', 'artist_count', 'released_year', 'released_month', 'released_day', 'released_date', 'season', 'day_of_week', 'in_spotify_playlists', 'in_spotify_charts', 'streams', 'bpm', 'key', 'mode', 'danceability_%', 'valence_%', 'energy_%', 'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%']]
df1.head()
# Out:
#                             track_name     main_artist supporting_artists  \
# 0  Seven (feat. Latto) (Explicit Ver.)           Latto          Jung Kook
# 1                                 LALA     Myke Towers                NaN
# 2                              vampire  Olivia Rodrigo                NaN
# 3                         Cruel Summer    Taylor Swift                NaN
# 4                       WHERE SHE GOES       Bad Bunny                NaN
#
#    artist_count  released_year  released_month  released_day released_date  \
# 0             2           2023               7            14    2023-07-14
# 1             1           2023               3            23    2023-03-23
# 2             1           2023               6            30    2023-06-30
# 3             1           2019               8            23    2019-08-23
# 4             1           2023               5            18    2023-05-18
#
# ...

# %%
#select random sample of 5 rows
df1.sample(5)
#show the streams of these samples
df1.sample(5)['streams']
# Out:
# 582      60680939
# 316     367814306
# 292    1449799467
# 884     273914335
# 750    1023187129
# Name: streams, dtype: int64

# %%
df1.shape
# Out:
# (952, 23)
